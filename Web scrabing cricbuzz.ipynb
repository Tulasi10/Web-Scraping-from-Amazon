# %%
! pip install beautifulsoup4

# %%
! pip install requests

# %%
import sys
import time
from bs4 import BeautifulSoup
import requests

# %%
try:
        
    page=requests.get('https://www.cricbuzz.com/')                            
    
except Exception as e:                                   
    error_type, error_obj, error_info = sys.exc_info()      
    print ('ERROR FOR LINK:',url)                          
    print (error_type, 'Line:', error_info.tb_lineno)     
                                                 
time.sleep(2)   
soup=BeautifulSoup(page.text,'html.parser')
links=soup.find_all('div',attrs={'class':'cb-nws-intr'})

# %%
page
# Out:
# <Response [200]>

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
links
# Out:
# [<div class="cb-nws-intr">Australia had come into the men's T20 World Cup at the back of several losses, questions on the coach and the players, but against odds went, on to secure their maiden title in the format</div>,
#  <div class="cb-nws-intr">In the end, it was about fine margins and a familiar tight corner for Kane Williamson and his team</div>,
#  <div class="cb-nws-intr">Haris Rauf, Imran Butt and Shahnawaz Dahani, who were part of the squad on the West Indies tour, miss out</div>,
#  <div class="cb-nws-intr">In the build-up to the New Zealand series, KL Rahul spoke about what India is likely to see with the new leadership group</div>,
#  <div class="cb-nws-intr">As Daryl Mitchell and Marcus Stoinis battle it out on the biggest stage of their lives under the watchful eyes of Justin Langer, there is a Perth connection that goes a decade back</div>,
# ...

# %%
for i in links:
    print(i.text)
    print("\n")
# Out:
# Australia had come into the men's T20 World Cup at the back of several losses, questions on the coach and the players, but against odds went, on to secure their maiden title in the format
#
#
# In the end, it was about fine margins and a familiar tight corner for Kane Williamson and his team
#
#
# Haris Rauf, Imran Butt and Shahnawaz Dahani, who were part of the squad on the West Indies tour, miss out
#
#
# In the build-up to the New Zealand series, KL Rahul spoke about what India is likely to see with the new leadership group
#
#
# As Daryl Mitchell and Marcus Stoinis battle it out on the biggest stage of their lives under the watchful eyes of Justin Langer, there is a Perth connection that goes a decade back
#
#
# Cricket has continued to overlook human rights issues in the UAE and Afghanistan to allow the show to go on. At what point should the ICC be taking a broader view, asks Isabelle Westbury in a new column for Cricbuzz Plus
#
#
# ...

# %%
try:
    
    page=requests.get('https://www.amazon.in/?&ext_vrnc=hi&tag=googhydrabk1-21&ref=pd_sl_7hz2t19t5c_e&adgrpid=58355126069&hvpone=&hvptwo=&hvadid=486386870127&hvpos=&hvnetw=g&hvrand=790921858514086367&hvqmt=e&hvdev=c&hvdvcmdl=&hvlocint=&hvlocphy=9040204&hvtargid=kwd-10573980&hydadcr=14453_2154373&gclid=CjwKCAiAp8iMBhAqEiwAJb94zyyhBkW5eHQHF3lmlGsL0lRMEgNQBQPNO_DI5jD9qH7guob_RoeKfhoCd6IQAvD_BwE')
    
except Exception as e:
        error_type, error_obj, error_info = sys.exc_info()
        print ('ERROR FOR LINK:',url)
        print ('ERROR FOR LINK:',url)
        
time.sleep(2)   
soup=BeautifulSoup(page.text,'html.parser')
links=soup.find_all('h2',attrs={'class':'a-color-base headline truncate-2line'})

# %%
page
# Out:
# <Response [200]>

# %%
soup
# Out:
# <!DOCTYPE html>
# <html class="a-no-js" data-19ax5a9jf="dingo" lang="en-in"><!-- sp:feature:head-start -->
# <head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>
# <!-- sp:end-feature:head-start -->
# <!-- sp:feature:cs-optimization -->
# <meta content="on" http-equiv="x-dns-prefetch-control"/>
# <link href="https://images-eu.ssl-images-amazon.com" rel="dns-prefetch"/>
# <link href="https://m.media-amazon.com" rel="dns-prefetch"/>
# <link href="https://completion.amazon.com" rel="dns-prefetch"/>
# <!-- sp:end-feature:cs-optimization -->
# <!-- sp:feature:aui-assets -->
# ...

# %%
links
# Out:
# [<h2 class="a-color-base headline truncate-2line">Bill payments got fast &amp; convenient</h2>,
#  <h2 class="a-color-base headline truncate-2line">Upgrade your home | Amazon Brands &amp; more</h2>,
#  <h2 class="a-color-base headline truncate-2line">Now save bill details &amp; get timely reminders</h2>,
#  <h2 class="a-color-base headline truncate-2line">Styles for Women | Up to 70% off</h2>,
#  <h2 class="a-color-base headline truncate-2line">Revamp your home in style</h2>,
#  <h2 class="a-color-base headline truncate-2line">Top picks for your home</h2>,
#  <h2 class="a-color-base headline truncate-2line">Automotive essentials | Up to 60% off</h2>,
#  <h2 class="a-color-base headline truncate-2line">Pay your credit card bills on Amazon</h2>,
#  <h2 class="a-color-base headline truncate-2line">Top rated, premium quality | Amazon Brands &amp; more</h2>,
#  <h2 class="a-color-base headline truncate-2line">Effective dishwashing for Indian cooking</h2>,
# ...

# %%
for i in links:
    print(i.text)
    print("\n")
# Out:
# Bill payments got fast & convenient
#
#
# Upgrade your home | Amazon Brands & more
#
#
# Now save bill details & get timely reminders
#
#
# Styles for Women | Up to 70% off
#
#
# Revamp your home in style
#
#
# Top picks for your home
#
#
# Automotive essentials | Up to 60% off
#
#
# Pay your credit card bills on Amazon
#
#
# Top rated, premium quality | Amazon Brands & more
#
#
# Effective dishwashing for Indian cooking
#
#
# Value Packs under ₹599 | Amazon Brands & more
#
#
# One stop shop for all your wedding shopping
#
#
# Computing peripherals & supplies
#
#
# Up to 60% off | Top deals on stationery supplies
#
#
# Up to 50% off | Garden & outdoor
#
#
# Bring joy with the perfect wedding gifts
#
#
# Electronics devices for home office
#
#
# JOIN PRIME today at ₹999/year
#
#
# Up to 45% off | Shop by Pet
#
#
# Upgrade your kitchen
